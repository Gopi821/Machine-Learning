# %%
import os
os.environ['GEMINI_API_KEY'] = 'AIzaSyC7ZXitBXCQXyEQTjt2o4xNMfJ9zrPB1bw'

# %%
import google.generativeai as genai
genai.configure(api_key = os.environ["GEMINI_API_KEY"] )

# %%
model = genai.GenerativeModel('gemini-2.0-flash-exp')

# %%
response = model.generate_content("what is life span of person.")
print(response.text)
# Out:
# The lifespan of a person is a complex and variable thing! There's no single, definitive answer because it depends on so many factors. Here's a breakdown of different ways to think about it:
#
# **1. Average Lifespan (Life Expectancy):**
#
# *   This is the **average number of years a person is expected to live** from birth, based on statistical analysis of a population.
# *   It's heavily influenced by factors like:
#     *   **Country/Region:** Developed countries generally have higher life expectancies than developing countries.
#     *   **Access to Healthcare:** Quality and availability of healthcare have a huge impact.
#     *   **Nutrition:** Adequate and healthy diets are essential.
#     *   **Sanitation:** Clean water and proper sanitation prevent disease.
#     *   **Socioeconomic Factors:** Poverty, education levels, and access to resources all play a role.
#     *   **Gender:** Historically, women have tended to live longer than men, although the gap is narrowing in some places.
#
# *   **Current Global Average:**  The current global average life expectancy is around **73 years** as of 2023. (Source: World Bank, WHO). However, this is just an average!
# *   **Examples by Country:**
#     *   Japan, Switzerland, and Singapore often have some of the highest life expectancies, often exceeding 80 years.
#     *   Countries in sub-Saharan Africa often have lower life expectancies, sometimes in the 50s or 60s, due to factors like poverty, disease, and conflict.
#
# **2. Maximum Lifespan:**
#
# *   This is the **absolute longest a human being has ever been recorded to live.**
# *   The current record holder is Jeanne Louise Calment, who lived to be 122 years and 164 days old.
# *   While average life expectancy has increased significantly over the past century, the maximum lifespan has remained relatively stable.
#
# **3. Factors Affecting Individual Lifespan:**
#
# *   **Genetics:**  Some people are genetically predisposed to longer lifespans or to certain diseases that can shorten lifespan.  However, genetics is only part of the story.
# *   **Lifestyle:** This is a huge one!
#     *   **Diet:** A healthy diet rich in fruits, vegetables, and whole grains is crucial.
#     *   **Exercise:** Regular physical activity has numerous health benefits.
#     *   **Smoking:** Smoking significantly reduces lifespan.
#     *   **Alcohol Consumption:** Excessive alcohol consumption is detrimental.
#     *   **Stress Management:** Chronic stress can negatively impact health.
#     *   **Sleep:** Adequate sleep is essential for overall well-being.
# *   **Environment:** Exposure to pollution, toxins, and other environmental hazards can affect lifespan.
# *   **Medical Conditions:**  Chronic diseases like heart disease, cancer, diabetes, and Alzheimer's disease can significantly shorten lifespan.
#
# **In summary:**
#
# *   The average lifespan (life expectancy) is a statistical measure that varies greatly depending on location and socioeconomic factors.
# *   The maximum lifespan is the longest a human has ever lived, which is currently 122 years.
# *   Individual lifespan is determined by a complex interplay of genetics, lifestyle, environment, and medical conditions.
#
# **Important Considerations:**
#
# *   **Life expectancy is not a guarantee.** It's a statistical prediction based on current trends. An individual may live much longer or shorter than the average.
# *   **Focus on healthspan, not just lifespan.**  It's not just about living a long time, but also about living a healthy and fulfilling life for as long as possible. This involves maintaining physical and mental well-being.

# %%
import pathlib
import textwrap

import google.generativeai as genai

from IPython.display import display
from IPython.display import Markdown

def to_markdown(text):
    text = text.replace('•', '  *')
    return Markdown(textwrap.indent(text,'> ',predicate=lambda _: True))

# %%
for m in genai.list_models():
    if 'generateContent' in m.supported_generation_methods:
        print(m.name)
# Out:
# models/gemini-1.0-pro-vision-latest
# models/gemini-pro-vision
# models/gemini-1.5-pro-latest
# models/gemini-1.5-pro-001
# models/gemini-1.5-pro-002
# models/gemini-1.5-pro
# models/gemini-1.5-flash-latest
# models/gemini-1.5-flash-001
# models/gemini-1.5-flash-001-tuning
# models/gemini-1.5-flash
# models/gemini-1.5-flash-002
# models/gemini-1.5-flash-8b
# models/gemini-1.5-flash-8b-001
# models/gemini-1.5-flash-8b-latest
# models/gemini-1.5-flash-8b-exp-0827
# models/gemini-1.5-flash-8b-exp-0924
# models/gemini-2.0-flash-exp
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-exp-image-generation
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.0-flash-lite-preview-02-05
# models/gemini-2.0-flash-lite-preview
# models/gemini-2.0-pro-exp
# models/gemini-2.0-pro-exp-02-05
# models/gemini-exp-1206
# models/gemini-2.0-flash-thinking-exp-01-21
# models/gemini-2.0-flash-thinking-exp
# models/gemini-2.0-flash-thinking-exp-1219
# models/learnlm-1.5-pro-experimental
# models/gemma-3-27b-it

# %% [markdown]
# # Multimodel image to text

# %%
import PIL.Image

img = PIL.Image.open(r'D:\veda\Elephant image.jpg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=540x360>

# %%
model = genai.GenerativeModel('models/gemini-2.0-pro-exp-02-05')

# %%
response = model.generate_content(img)

to_markdown(response.text)
# Out:
# > The elephant is in a field of green grass with low mountains in the background covered by clouds.
